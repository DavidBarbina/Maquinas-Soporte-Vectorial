# %%
import pandas as pd
import pylab as pl
import numpy as np
import scipy.optimize as opt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

file_id = "1NlY7I_XVgZWCj6A-BJKlL2076WKOyPqc"
url = f"https://drive.google.com/uc?export=download&id={file_id}"
df = pd.read_csv(url)


df = pd.get_dummies(df, columns=["sales","salary"], dtype=int)

y = df.left.values
x_df = df.drop(["left"], axis=1)

# Normalización
x = (x_df - x_df.min()) / (x_df.max() - x_df.min())

feature_df = df[["satisfaction_level","last_evaluation", "number_project","average_montly_hours","time_spend_company","Work_accident", "promotion_last_5years"]]
X = np.asarray(feature_df)

# Creación de grupos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20, random_state=4)
print("Grupo de entrenamiento" , X_train.shape, y_train.shape)
print("G>rupo de prueba", X_test.shape, y_test.shape)

from sklearn import svm
clf = svm.SVC(kernel="rbf")
clf.fit(X_train, y_train)

# Predicción para la base de prueba
yhat = clf.predict(X_test)

# Creación de matriz de confusión
from sklearn.metrics import confusion_matrix
y_pred = clf.predict(X)
cm = confusion_matrix(y_test,yhat)

# Visualización de la matriz de confusión
import seaborn as sns
f, ax = plt.subplots(figsize=(5,5))

sns.heatmap(cm, annot=True, linewidths=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y pronosticada")
plt.ylabel("y real")
plt.show()

from sklearn.metrics import classification_report
cnf_matrix = confusion_matrix(y_test, yhat, labels=[0,1])
print(classification_report(y_test,yhat))

nuevo = [0.5, 0.75, 4, 200, 4,0,0]
clf.predict([nuevo])
# Out:
# Grupo de entrenamiento (11999, 7) (11999,)
# G>rupo de prueba (3000, 7) (3000,)
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88      2287
#            1       1.00      0.08      0.16       713
#
#     accuracy                           0.78      3000
#    macro avg       0.89      0.54      0.52      3000
# weighted avg       0.83      0.78      0.70      3000
# array([0])

# %%
clf = svm.SVC(kernel="linear")
clf.fit(X_train, y_train)

# Predicción para la base de prueba
yhat = clf.predict(X_test)

# Creación de matriz de confusión
from sklearn.metrics import confusion_matrix
y_pred = clf.predict(X)
cm = confusion_matrix(y_test,yhat)

# Visualización de la matriz de confusión
import seaborn as sns
f, ax = plt.subplots(figsize=(5,5))

sns.heatmap(cm, annot=True, linewidths=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y pronosticada")
plt.ylabel("y real")
plt.show()

from sklearn.metrics import classification_report
cnf_matrix = confusion_matrix(y_test, yhat, labels=[0,1])
print(classification_report(y_test,yhat))

nuevo = [0.5, 0.75, 4, 200, 4,0,0]
clf.predict([nuevo])
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.95      0.87      2287
#            1       0.60      0.26      0.36       713
#
#     accuracy                           0.78      3000
#    macro avg       0.70      0.60      0.61      3000
# weighted avg       0.76      0.78      0.75      3000
# array([0])

# %%
clf = svm.SVC(kernel="poly")
clf.fit(X_train, y_train)

# Predicción para la base de prueba
yhat = clf.predict(X_test)

# Creación de matriz de confusión
from sklearn.metrics import confusion_matrix
y_pred = clf.predict(X)
cm = confusion_matrix(y_test,yhat)

# Visualización de la matriz de confusión
import seaborn as sns
f, ax = plt.subplots(figsize=(5,5))

sns.heatmap(cm, annot=True, linewidths=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y pronosticada")
plt.ylabel("y real")
plt.show()

from sklearn.metrics import classification_report
cnf_matrix = confusion_matrix(y_test, yhat, labels=[0,1])
print(classification_report(y_test,yhat))

nuevo = [0.5, 0.75, 4, 200, 4,0,0]
clf.predict([nuevo])
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.87      2287
#            1       0.00      0.00      0.00       713
#
#     accuracy                           0.76      3000
#    macro avg       0.38      0.50      0.43      3000
# weighted avg       0.58      0.76      0.66      3000
# array([0])

# %%
clf = svm.SVC(kernel="sigmoid")
clf.fit(X_train, y_train)

# Predicción para la base de prueba
yhat = clf.predict(X_test)

# Creación de matriz de confusión
from sklearn.metrics import confusion_matrix
y_pred = clf.predict(X)
cm = confusion_matrix(y_test,yhat)

# Visualización de la matriz de confusión
import seaborn as sns
f, ax = plt.subplots(figsize=(5,5))

sns.heatmap(cm, annot=True, linewidths=0.5, linecolor="red", fmt=".0f", ax=ax)
plt.xlabel("y pronosticada")
plt.ylabel("y real")
plt.show()

from sklearn.metrics import classification_report
cnf_matrix = confusion_matrix(y_test, yhat, labels=[0,1])
print(classification_report(y_test,yhat))

nuevo = [0.5, 0.75, 4, 200, 4,0,0]
clf.predict([nuevo])
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82      2287
#            1       0.41      0.39      0.40       713
#
#     accuracy                           0.72      3000
#    macro avg       0.61      0.61      0.61      3000
# weighted avg       0.72      0.72      0.72      3000
# array([0])
